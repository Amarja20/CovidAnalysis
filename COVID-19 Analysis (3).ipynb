# %% [markdown]
# ##Objective

# %% [markdown]
# 1. Exploratory analysis of COVID 19 cases  for four different nations in the United Kingdom.
# 2. Data Visualization of the projected patterns for analysis.
# 3. Comparing the Covid cases in the United Kingdoms with cases in other countries such as Korean and India.

# %%
import pyspark.sql.functions as F 
from pyspark.sql.types import *
import matplotlib.pyplot as plt
import plotly.express as ex

# %% [markdown]
# ## Data preprocessing

# %%
df_UnitedKingdom= spark.read.csv('/FileStore/tables/UK_Devolved_Nations_COVID19_2021_Dataset-3.csv', header = True, inferSchema = True )
df_PopulationData = spark.read.csv('/FileStore/tables/Populations_for_UK_and_Devolved_Nations.csv', header = True, inferSchema = True )

# %%
df_UnitedKingdom = df_UnitedKingdom.na.drop()
df_UnitedKingdom.show()
# Out:
# +----------+--------+---------+-----------------+----------+---------------+
# |      date|areaName|MildCases|HospitalisedCases|CasesCured|ConfirmedDeaths|
# +----------+--------+---------+-----------------+----------+---------------+
# |2020-03-26|   Wales|      113|              203|        36|              6|
# |2020-03-27|   Wales|      180|              243|        37|              6|
# |2020-03-28|   Wales|      172|              310|        53|              4|
# |2020-03-29|   Wales|      148|              329|        71|             10|
# |2020-04-19|   Wales|      334|              828|       153|             41|
# |2020-04-20|   Wales|      276|              853|       150|              9|
# |2020-04-21|   Wales|      304|              838|       135|             25|
# |2020-04-22|   Wales|      274|              773|       132|             15|
# |2020-04-23|   Wales|      234|              741|       123|             17|
# |2020-04-24|   Wales|      243|              743|       119|            110|
# |2020-04-25|   Wales|      299|              719|       126|             23|
# |2020-04-26|   Wales|      178|              710|       111|             14|
# |2020-04-27|   Wales|      203|              734|       105|              8|
# |2020-04-28|   Wales|      232|              676|       107|             17|
# |2020-04-29|   Wales|      117|              664|       101|             73|
# |2020-04-30|   Wales|      183|              643|        99|             22|
# |2020-05-01|   Wales|      160|              529|        92|             17|
# |2020-05-02|   Wales|      183|              521|        93|             44|
# |2020-05-03|   Wales|      174|              539|        94|             14|
# |2020-05-04|   Wales|      195|              538|        92|             14|
# +----------+--------+---------+-----------------+----------+---------------+
# only showing top 20 rows

# %%
df_UnitedKingdom = df_UnitedKingdom.withColumnRenamed("areaName", "Nation")
df_UnitedKingdom.show(5)
# Out:
# +----------+------+---------+-----------------+----------+---------------+
# |      date|Nation|MildCases|HospitalisedCases|CasesCured|ConfirmedDeaths|
# +----------+------+---------+-----------------+----------+---------------+
# |2020-03-26| Wales|      113|              203|        36|              6|
# |2020-03-27| Wales|      180|              243|        37|              6|
# |2020-03-28| Wales|      172|              310|        53|              4|
# |2020-03-29| Wales|      148|              329|        71|             10|
# |2020-04-19| Wales|      334|              828|       153|             41|
# +----------+------+---------+-----------------+----------+---------------+
# only showing top 5 rows

# %%
df_UnitedKingdom = df_PopulationData.join(df_UnitedKingdom, on = 'Nation', how = 'inner')
df_UnitedKingdom.show(5)
# Out:
# +------+---+------------------+----------+---------+-----------------+----------+---------------+
# |Nation|_c0|        Population|      date|MildCases|HospitalisedCases|CasesCured|ConfirmedDeaths|
# +------+---+------------------+----------+---------+-----------------+----------+---------------+
# | Wales|  2|3169607.2851451337|2020-03-26|      113|              203|        36|              6|
# | Wales|  2|3169607.2851451337|2020-03-27|      180|              243|        37|              6|
# | Wales|  2|3169607.2851451337|2020-03-28|      172|              310|        53|              4|
# | Wales|  2|3169607.2851451337|2020-03-29|      148|              329|        71|             10|
# | Wales|  2|3169607.2851451337|2020-04-19|      334|              828|       153|             41|
# +------+---+------------------+----------+---------+-----------------+----------+---------------+
# only showing top 5 rows

# %%
df_UnitedKingdom.na.drop()
df_UnitedKingdom = df_UnitedKingdom.drop("_c0")
df_UnitedKingdom.show(5)
# Out:
# +------+------------------+----------+---------+-----------------+----------+---------------+
# |Nation|        Population|      date|MildCases|HospitalisedCases|CasesCured|ConfirmedDeaths|
# +------+------------------+----------+---------+-----------------+----------+---------------+
# | Wales|3169607.2851451337|2020-03-26|      113|              203|        36|              6|
# | Wales|3169607.2851451337|2020-03-27|      180|              243|        37|              6|
# | Wales|3169607.2851451337|2020-03-28|      172|              310|        53|              4|
# | Wales|3169607.2851451337|2020-03-29|      148|              329|        71|             10|
# | Wales|3169607.2851451337|2020-04-19|      334|              828|       153|             41|
# +------+------------------+----------+---------+-----------------+----------+---------------+
# only showing top 5 rows

# %%
## Total active cases
df_UnitedKingdom = df_UnitedKingdom.withColumn('ActiveCases', ((df_UnitedKingdom["MildCases"] + df_UnitedKingdom["HospitalisedCases"])-df_UnitedKingdom["CasesCured"]-df_UnitedKingdom["ConfirmedDeaths"]))
df_UnitedKingdom.show(10)
display(df_UnitedKingdom)
# Out:
# +------+------------------+----------+---------+-----------------+----------+---------------+-----------+
# |Nation|        Population|      date|MildCases|HospitalisedCases|CasesCured|ConfirmedDeaths|ActiveCases|
# +------+------------------+----------+---------+-----------------+----------+---------------+-----------+
# | Wales|3169607.2851451337|2020-03-26|      113|              203|        36|              6|        274|
# | Wales|3169607.2851451337|2020-03-27|      180|              243|        37|              6|        380|
# | Wales|3169607.2851451337|2020-03-28|      172|              310|        53|              4|        425|
# | Wales|3169607.2851451337|2020-03-29|      148|              329|        71|             10|        396|
# | Wales|3169607.2851451337|2020-04-19|      334|              828|       153|             41|        968|
# | Wales|3169607.2851451337|2020-04-20|      276|              853|       150|              9|        970|
# | Wales|3169607.2851451337|2020-04-21|      304|              838|       135|             25|        982|
# | Wales|3169607.2851451337|2020-04-22|      274|              773|       132|             15|        900|
# | Wales|3169607.2851451337|2020-04-23|      234|              741|       123|             17|        835|
# | Wales|3169607.2851451337|2020-04-24|      243|              743|       119|            110|        757|
# +------+------------------+----------+---------+-----------------+----------+---------------+-----------+
# only showing top 10 rows
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Nation</th><th>Population</th><th>date</th><th>MildCases</th><th>HospitalisedCases</th><th>CasesCured</th><th>ConfirmedDeaths</th><th>ActiveCases</th></tr></thead><tbody><tr><td>Wales</td><td>3169607.2851451337</td><td>2020-03-26</td><td>113</td><td>203</td><td>36</td><td>6</td><td>274</td></tr><tr><td>Wales</td><td>3169607.2851451337</td><td>2020-03-27</td><td>180</td><td>243</td><td>37</td><td>6</td><td>380</td></tr><tr><td>Wales</td><td>3169607.2851451337</td><td>2020-03-28</td><td>172</td><td>310</td><td>53</td><td>4</td><td>425</td></tr><tr><td>Wales</td><td>3169607.2851451337</td><td>2020-03-29</td><td>148</td><td>329</td><td>71</td><td>10</td><td>396</td></tr><tr><td>Wales</td><td>3169607.2851451337</td><td>2020-04-19</td><td>334</td><td>828</td><td>153</td><td>41</td><td>968</td></tr><tr><td>Wales</td><td>3169607.2851451337</td><td>2020-04-20</td><td>276</td><td>853</td><td>150</td><td>9</td><td>970</td></tr><tr><td>Wales</td><td>3169607.2851451337</td><td>2020-04-21</td><td>304</td><td>838</td><td>135</td><td>25</td><td>982</td></tr><tr><td>Wales</td><td>3169607.2851451337</td><td>2020-04-22</td><td>274</td><td>773</td><td>132</td><td>15</td><td>900</td></tr><tr><td>Wales</td><td>3169607.2851451337</td><td>2020-04-23</td><td>234</td><td>741</td><td>123</td><td>17</td><td>835</td></tr><tr><td>Wales</td><td>3169607.2851451337</td><td>2020-04-24</td><td>243</td><td>743</td><td>119</td><td>110</td><td>757</td></tr><tr><td>Wales</td><td>3169607.2851451337</td><td>2020-04-25</td><td>299</td><td>719</td><td>126</td><td>23</td><td>869</td></tr><tr><td>Wales</td><td>3169607.2851451337</td><td>2020-04-26</td><td>178</td><td>710</td><td>111</td><td>14</td><td>763</td></tr><tr><td>Wales</td><td>3169607.2851451337</td><td>2020-04-27</td><td>203</td><td>734</td><td>105</td><td>8</td><td>824</td></tr><tr><td>Wales</td><td>3169607.2851451337</td><td>2020-04-28</td><td>232</td><td>676</td><td>107</td><td>17</td><td>784</td></tr><tr><td>Wales</td><td>3169607.2851451337</td><td>2020-04-29</td><td>117</td><td>664</td><td>101</td><td>73</td><td>607</td></tr><tr><td>Wales</td><td>3169607.2851451337</td><td>2020-04-30</td><td>183</td><td>643</td><td>99</td><td>22</td><td>705</td></tr><tr><td>Wales</td><td>3169607.2851451337</td><td>2020-05-01</td><td>160</td><td>529</td><td>92</td><td>17</td><td>580</td></tr><tr><td>Wales</td><td>3169607.2851451337</td><td>2020-05-02</td><td>183</td><td>521</td><td>93</td><td>44</td><td>567</td></tr><tr><td>Wales</td><td>3169607.2851451337</td><td>2020-05-03</td><td>174</td><td>539</td><td>94</td><td>14</td><td>605</td></tr><tr><td>Wales</td><td>3169607.2851451337</td><td>2020-05-04</td><td>195</td><td>538</td><td>92</td><td>14</td><td>627</td></tr><tr><td>Wales</td><td>3169607.2851451337</td><td>2020-05-05</td><td>145</td><td>501</td><td>87</td><td>26</td><td>533</td></tr><tr><td>Wales</td><td>3169607.2851451337</td><td>2020-05-06</td><td>95</td><td>478</td><td>81</td><td>21</td><td>471</td></tr><tr><td>Wales</td><td>3169607.2851451337</td><td>2020-05-07</td><td>87</td><td>470</td><td>84</td><td>18</td><td>455</td></tr><tr><td>Wales</td><td>3169607.2851451337</td><td>2020-05-08</td><td>152</td><td>416</td><td>89</td><td>28</td><td>451</td></tr><tr><td>Wales</td><td>3169607.2851451337</td><td>2020-05-09</td><td>118</td><td>448</td><td>75</td><td>9</td><td>482</td></tr><tr><td>Wales</td><td>3169607.2851451337</td><td>2020-05-10</td><td>223</td><td>461</td><td>78</td><td>12</td><td>594</td></tr><tr><td>Wales</td><td>3169607.2851451337</td><td>2020-05-11</td><td>124</td><td>465</td><td>76</td><td>5</td><td>508</td></tr><tr><td>Wales</td><td>3169607.2851451337</td><td>2020-05-12</td><td>105</td><td>425</td><td>72</td><td>16</td><td>442</td></tr><tr><td>Wales</td><td>3169607.2851451337</td><td>2020-05-13</td><td>133</td><td>394</td><td>66</td><td>22</td><td>439</td></tr><tr><td>Wales</td><td>316 ...

# %%
## Rearranging columns
df_UnitedKingdom = df_UnitedKingdom.select("date","Nation","Population","MildCases","HospitalisedCases","CasesCured","ConfirmedDeaths","ActiveCases")

# %%
df_UnitedKingdom.groupBy("Nation").sum("MildCases", "HospitalisedCases").show()
# Out:
# +----------------+--------------+----------------------+
# |          Nation|sum(MildCases)|sum(HospitalisedCases)|
# +----------------+--------------+----------------------+
# |           Wales|        494264|                280843|
# |         England|       4608297|               2840563|
# |        Scotland|        377049|                246445|
# |Northern Ireland|        191121|                125821|
# +----------------+--------------+----------------------+

# %%
## Cases in Wales
df_wales = df_UnitedKingdom.filter(df_UnitedKingdom["Nation"]=="Wales")
df_wales.show(5)
# Out:
# +----------+------+------------------+---------+-----------------+----------+---------------+-----------+
# |      date|Nation|        Population|MildCases|HospitalisedCases|CasesCured|ConfirmedDeaths|ActiveCases|
# +----------+------+------------------+---------+-----------------+----------+---------------+-----------+
# |2020-03-26| Wales|3169607.2851451337|      113|              203|        36|              6|        274|
# |2020-03-27| Wales|3169607.2851451337|      180|              243|        37|              6|        380|
# |2020-03-28| Wales|3169607.2851451337|      172|              310|        53|              4|        425|
# |2020-03-29| Wales|3169607.2851451337|      148|              329|        71|             10|        396|
# |2020-04-19| Wales|3169607.2851451337|      334|              828|       153|             41|        968|
# +----------+------+------------------+---------+-----------------+----------+---------------+-----------+
# only showing top 5 rows

# %%
## Cases in Scotland
df_scotland = df_UnitedKingdom.filter(df_UnitedKingdom["Nation"]=="Scotland")
df_scotland.show(5)
# Out:
# +----------+--------+-----------------+---------+-----------------+----------+---------------+-----------+
# |      date|  Nation|       Population|MildCases|HospitalisedCases|CasesCured|ConfirmedDeaths|ActiveCases|
# +----------+--------+-----------------+---------+-----------------+----------+---------------+-----------+
# |2020-03-27|Scotland|5466257.668711656|      165|              404|        72|              8|        489|
# |2020-03-28|Scotland|5466257.668711656|      186|              511|        81|              7|        609|
# |2020-03-29|Scotland|5466257.668711656|      139|              565|        95|              1|        608|
# |2020-03-30|Scotland|5466257.668711656|      179|              627|       108|              6|        692|
# |2020-03-31|Scotland|5466257.668711656|      430|              752|       135|             22|       1025|
# +----------+--------+-----------------+---------+-----------------+----------+---------------+-----------+
# only showing top 5 rows

# %%
## Total cases in scotland
df_UnitedKingdom.filter((df_UnitedKingdom['Nation'] == "Scotland") & (df_UnitedKingdom['MildCases'] > 0) & (df_UnitedKingdom['HospitalisedCases'] > 0)).count()
# Out:
# Out[12]: 426

# %%
## Total cases in Wales
df_UnitedKingdom.filter((df_UnitedKingdom['Nation'] == "Wales") & (df_UnitedKingdom['MildCases'] > 0) & (df_UnitedKingdom['HospitalisedCases'] > 0)).count()
# Out:
# Out[13]: 476

# %%
df_uk_latest_cases=df_UnitedKingdom.groupBy("date").sum().sort("date",ascending=True)
df_uk_latest_cases.select('date','sum(MildCases)', 'sum(HospitalisedCases)').toPandas().style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_b905b_row0_col1, #T_b905b_row0_col2, #T_b905b_row4_col1, #T_b905b_row74_col1, #T_b905b_row76_col1, #T_b905b_row89_col1, #T_b905b_row90_col1, #T_b905b_row91_col1, #T_b905b_row92_col1, #T_b905b_row93_col1, #T_b905b_row94_col1, #T_b905b_row95_col1, #T_b905b_row96_col1, #T_b905b_row97_col1, #T_b905b_row98_col1, #T_b905b_row99_col1, #T_b905b_row100_col1, #T_b905b_row101_col1, #T_b905b_row102_col1, #T_b905b_row103_col1, #T_b905b_row104_col1, #T_b905b_row105_col1, #T_b905b_row106_col1, #T_b905b_row121_col1, #T_b905b_row121_col2, #T_b905b_row122_col1, #T_b905b_row122_col2, #T_b905b_row123_col1, #T_b905b_row123_col2, #T_b905b_row124_col1, #T_b905b_row124_col2, #T_b905b_row125_col1, #T_b905b_row125_col2, #T_b905b_row126_col1, #T_b905b_row126_col2, #T_b905b_row127_col1, #T_b905b_row127_col2, #T_b905b_row128_col1, #T_b905b_row128_col2, #T_b905b_row129_col1, #T_b905b_row129_col2, #T_b905b_row130_col1, #T_b905b_row130_col2, #T_b905b_row131_col1, #T_b905b_row131_col2, #T_b905b_row132_col1, #T_b905b_row132_col2, #T_b905b_row133_col1, #T_b905b_row133_col2, #T_b905b_row134_col1, #T_b905b_row134_col2, #T_b905b_row135_col1, #T_b905b_row135_col2, #T_b905b_row136_col1, #T_b905b_row136_col2, #T_b905b_row137_col1, #T_b905b_row137_col2, #T_b905b_row138_col1, #T_b905b_row138_col2, #T_b905b_row281_col1, #T_b905b_row568_col1, #T_b905b_row575_col1, #T_b905b_row582_col1, #T_b905b_row589_col1, #T_b905b_row595_col2, #T_b905b_row596_col1, #T_b905b_row596_col2, #T_b905b_row597_col2, #T_b905b_row598_col2, #T_b905b_row599_col2, #T_b905b_row600_col2, #T_b905b_row601_col2, #T_b905b_row602_col2, #T_b905b_row603_col1, #T_b905b_row603_col2, #T_b905b_row605_col1, #T_b905b_row610_col1, #T_b905b_row612_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_b905b_row1_col1, #T_b905b_row2_col1, #T_b905b_row3_col1, #T_b905b_row6_col1, #T_b905b_row40_col1, #T_b905b_row42_col1, #T_b905b_row43_col1, #T_b905b_row44_col1, #T_b905b_row66_col1, #T_b905b_row67_col1, #T_b905b_row73_col1, #T_b905b_row77_col1, #T_b905b_row80_col1, #T_b905b_row81_col1, #T_b905b_row82_col1, #T_b905b_row83_col1, #T_b905b_row84_col1, #T_b905b_row85_col1, #T_b905b_row86_col1, #T_b905b_row87_col1, #T_b905b_row88_col1, #T_b905b_row106_col2, #T_b905b_row110_col1, #T_b905b_row571_col2, #T_b905b_row572_col2, #T_b905b_row573_col2, #T_b905b_row574_col2, #T_b905b_row575_col2, #T_b905b_row576_col2, #T_b905b_row577_col2, #T_b905b_row578_col2, #T_b905b_row579_col2, #T_b905b_row580_col2, #T_b905b_row581_col2, #T_b905b_row582_col2, #T_b905b_row583_col2, #T_b905b_row584_col2, #T_b905b_row585_col2, #T_b905b_row586_col2, #T_b905b_row587_col2, #T_b905b_row588_col2, #T_b905b_row589_col2, #T_b905b_row590_col2, #T_b905b_row591_col2, #T_b905b_row592_col2, #T_b905b_row593_col2, #T_b905b_row594_col2, #T_b905b_row604_col2, #T_b905b_row605_col2, #T_b905b_row606_col2, #T_b905b_row607_col2 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_b905b_row1_col2, #T_b905b_row4_col2, #T_b905b_row5_col1, #T_b905b_row21_col1, #T_b905b_row22_col1, #T_b905b_row23_col1, #T_b905b_row25_col1, #T_b905b_row26_col1, #T_b905b_row31_col1, #T_b905b_row32_col1, #T_b905b_row33_col1, #T_b905b_row34_col1, #T_b905b_row35_col1, #T_b905b_row36_col1, #T_b905b_row37_col1, #T_b905b_row38_col1, #T_b905b_row39_col1, #T_b905b_row41_col1, #T_b905b_row45_col1, #T_b905b_row63_col1, #T_b905b_row68_col1, #T_b905b_row69_col1, #T_b905b_row70_col1, #T_b905b_row71_col1, #T_b905b_row72_col1, #T_b905b_row78_col1, #T_b905b_row79_col1, #T_b905b_row99_col2, #T_b905b_row100_col2, #T_b905b_row101_col2, #T_b905b_row102_col2, #T_b905b_row103_col2, #T_b905b_row104_col2, #T_b905b_row105_col2, #T_b905b_row109_col1, #T_b905b_row111_col1, #T_b905b_row116_col1, #T_b905b_row117_col1, #T_b905b_row118_col1, #T_b905b_row568_col2, #T_b905b_row569_col2, #T_b905b_row570_col2 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_b905b_row2_col2, #T_b905b_row3_col2, #T_b905b_row6_col2, #T_b905b_row24_col1, #T_b905b_row52_col1, #T_b905b_row53_col1, #T_b905b_row55_col1, #T_b905b_row89_col2, #T_b905b_row139_col1, #T_b905b_row139_col2, #T_b905b_row140_col2, #T_b905b_row141_col2, #T_b905b_row142_col1, #T_b905b_row142_col2, #T_b905b_row143_col1, #T_b905b_row143_col2, #T_b905b_row144_col2, #T_b905b_row145_col1, #T_b905b_row145_col2, #T_b905b_row146_col2, #T_b905b_row148_col1, #T_b905b_row148_col2, #T_b905b_row149_col2, #T_b905b_row150_col2, #T_b905b_row151_col1, #T_b905b_row151_col2, #T_b905b_row153_col1, #T_b905b_row156_col1, #T_b905b_row165_col2, #T_b905b_row166_col2, #T_b905b_row167_col2, #T_b905b_row168_col2, #T_b905b_row172_col2, #T_b905b_row413_col2, #T_b905b_row414_col2, #T_b905b_row415_col2, #T_b905b_row416_col2, #T_b905b_row417_col2, #T_b905b_row418_col2, #T_b905b_row419_col2, #T_b905b_row420_col2, #T_b905b_row421_col2, #T_b905b_row422_col2, #T_b905b_row423_col2, #T_b905b_row424_col2, #T_b905b_row425_col2, #T_b905b_row426_col2, #T_b905b_row427_col2, #T_b905b_row428_col2, #T_b905b_row429_col2, #T_b905b_row430_col2, #T_b905b_row431_col2, #T_b905b_row432_col2, #T_b905b_row433_col2, #T_b905b_row434_col2, #T_b905b_row435_col2, #T_b905b_row436_col2, #T_b905b_row437_col2, #T_b905b_row547_col2, #T_b905b_row548_col2, #T_b905b_row553_col2, #T_b905b_row554_col2, #T_b905b_row555_col2, #T_b905b_row556_col2, #T_b905b_row557_col2, #T_b905b_row558_col2, #T_b905b_row559_col2, #T_b905b_row560_col2, #T_b905b_row561_col2, #T_b905b_row562_col2, #T_b905b_row563_col2, #T_b905b_row564_col2, #T_b905b_row565_col2, #T_b905b_row566_col2, #T_b905b_row567_col2, #T_b905b_row608_col2, #T_b905b_row609_col2 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_b905b_row5_col2, #T_b905b_row27_col1, #T_b905b_row28_col1, #T_b905b_row29_col1, #T_b905b_row30_col1, #T_b905b_row59_col1, #T_b905b_row60_col1, #T_b905b_row61_col1, #T_b905b_row62_col1, #T_b905b_row64_col1, #T_b905b_row65_col1, #T_b905b_row75_col1, #T_b905b_row90_col2, #T_b905b_row91_col2, #T_b905b_row92_col2, #T_b905b_row93_col2, #T_b905b_row94_col2, #T_b905b_row95_col2, #T_b905b_row96_col2, #T_b905b_row97_col2, #T_b905b_row98_col2, #T_b905b_row107_col1, #T_b905b_row108_col1, #T_b905b_row112_col1, #T_b905b_row113_col1, #T_b905b_row114_col1, #T_b905b_row115_col1, #T_b905b_row119_col1, #T_b905b_row120_col1, #T_b905b_row144_col1, #T_b905b_row146_col1, #T_b905b_row147_col2, #T_b905b_row152_col2, #T_b905b_row153_col2, #T_b905b_row154_col2, #T_b905b_row155_col2, #T_b905b_row156_col2, #T_b905b_row157_col2, #T_b905b_row158_col2, #T_b905b_row159_col2, #T_b905b_row160_col2, #T_b905b_row161_col2, #T_b905b_row162_col2, #T_b905b_row163_col2, #T_b905b_row164_col2, #T_b905b_row169_col2, #T_b905b_row170_col2, #T_b905b_row171_col2, #T_b905b_row243_col1 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_b905b_row7_col1, #T_b905b_row8_col1, #T_b905b_row17_col1, #T_b905b_row176_col1, #T_b905b_row193_col2, #T_b905b_row278_col1, #T_b905b_row288_col1, #T_b905b_row353_col1, #T_b905b_row358_col1, #T_b905b_row372_col2, #T_b905b_row373_col2, #T_b905b_row374_col2, #T_b905b_row375_col2, #T_b905b_row428_col1, #T_b905b_row538_col1, #T_b905b_row577_col1 {
#   background-color: #fee8de;
#   color: #000000;
# }
# #T_b905b_row7_col2, #T_b905b_row457_col1 {
#   background-color: #fc9e80;
#   color: #000000;
# }
# #T_b905b_row8_col2, #T_b905b_row247_col2, #T_b905b_row251_col2, #T_b905b_row259_col1, #T_b905b_row311_col1, #T_b905b_row336_col2 {
#   background-color: #fc9272;
#   color: #000000;
# }
# #T_b905b_row9_col1, #T_b905b_row11_col1, #T_b905b_row12_col1, #T_b905b_row24_col2, #T_b905b_row25_col2, #T_b905b_row169_col1, #T_b905b_row170_col1, #T_b905b_row191_col2, #T_b905b_row221_col2, #T_b905b_row222_col2, #T_b905b_row223_col2, #T_b905b_row225_col2, #T_b905b_row278_col2, #T_b905b_row279_col2, #T_b905b_row280_col2, #T_b905b_row281_col2, #T_b905b_row282_col2, #T_b905b_row285_col1, #T_b905b_row373_col1, #T_b905b_row378_col2, #T_b905b_row379_col2, #T_b905b_row382_col1, #T_b905b_row427_col1, #T_b905b_row429_col1, #T_b905b_row431_col1, #T_b905b_row469_col2, #T_b905b_row597_col1, #T_b905b_row617_col1 {
#   background-color:

# %%
df_uk_latest_cases=df_UnitedKingdom.groupBy("Nation", "date").sum().sort("sum(ConfirmedDeaths)", ascending=False)
df_uk_latest_cases.select("date", "Nation",'sum(MildCases)','sum(HospitalisedCases)','sum(CasesCured)','sum(ConfirmedDeaths)','sum(ActiveCases)').toPandas().style.background_gradient(cmap='Reds')
df_uk_latest_cases = df_uk_latest_cases.toPandas()
plot = df_uk_latest_cases.melt(id_vars="date", value_vars=['sum(CasesCured)',"sum(ConfirmedDeaths)","sum(ActiveCases)"])
matt = ex.treemap(plot, path=['variable'], values="value", height=500, width=800,
                color_discrete_sequence=["red","blue","green"])
matt.show()
# Out:
# /databricks/python/lib/python3.9/site-packages/plotly/express/_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="91089500-2d5f-40b9-8187-8838a97f4ec3" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("91089500-2d5f-40b9-8187-8838a97f4ec3")) {                    Plotly.newPlot(                        "91089500-2d5f-40b9-8187-8838a97f4ec3",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>value=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["sum(ActiveCases)","sum(CasesCured)","sum(ConfirmedDeaths)"],"labels":["sum(ActiveCases)","sum(CasesCured)","sum(ConfirmedDeaths)"],"name":"","parents":["","",""],"values":[8678659,398017,87727],"type":"treemap"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatte ...

# %% [markdown]
# ## Death cases in all 4 regions

# %%
df_state_death_cases = df_UnitedKingdom.filter(df_UnitedKingdom["ConfirmedDeaths"]>0)
df_state_death_cases.sort(df_state_death_cases["ConfirmedDeaths"].desc())
display(df_state_death_cases)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date</th><th>Nation</th><th>Population</th><th>MildCases</th><th>HospitalisedCases</th><th>CasesCured</th><th>ConfirmedDeaths</th><th>ActiveCases</th></tr></thead><tbody><tr><td>2020-03-26</td><td>Wales</td><td>3169607.2851451337</td><td>113</td><td>203</td><td>36</td><td>6</td><td>274</td></tr><tr><td>2020-03-27</td><td>Wales</td><td>3169607.2851451337</td><td>180</td><td>243</td><td>37</td><td>6</td><td>380</td></tr><tr><td>2020-03-28</td><td>Wales</td><td>3169607.2851451337</td><td>172</td><td>310</td><td>53</td><td>4</td><td>425</td></tr><tr><td>2020-03-29</td><td>Wales</td><td>3169607.2851451337</td><td>148</td><td>329</td><td>71</td><td>10</td><td>396</td></tr><tr><td>2020-04-19</td><td>Wales</td><td>3169607.2851451337</td><td>334</td><td>828</td><td>153</td><td>41</td><td>968</td></tr><tr><td>2020-04-20</td><td>
...
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# ##Confirmed, Active, Death Cases over a period of 2 years

# %%
graph = df_UnitedKingdom.groupby('date').sum().toPandas()
graph = graph.melt(id_vars='date', value_vars=['sum(CasesCured)', 'sum(ConfirmedDeaths)', 'sum(ActiveCases)'],
         var_name='Case', value_name='No. of Cases')
graph.head()
fig=ex.area(graph, x='date', y='No. of Cases', color='Case', title = 'Cases over a period of 2 years', color_discrete_sequence=["red", "blue", "green"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="2c2038e7-a1a5-4bfd-89ce-85b41a32c5c5" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2c2038e7-a1a5-4bfd-89ce-85b41a32c5c5")) {                    Plotly.newPlot(                        "2c2038e7-a1a5-4bfd-89ce-85b41a32c5c5",                        [{"hovertemplate":"Case=sum(CasesCured)<br>date=%{x}<br>No. of Cases=%{y}<extra></extra>","legendgroup":"sum(CasesCured)","line":{"color":"red"},"marker":{"symbol":"circle"},"mode":"lines","name":"sum(CasesCured)","orientation":"v","showlegend":true,"stackgroup":"1","x":["2020-08-24","2021-01-27","2021-06-22","2021-12-18","2021-10-11","2021-08-27","2020-11-29","2021-11-25","2020-07-24","2020-08-05","2021-10-02","2020-04-30","2020-08-28","2020-08-29","2020-10-04","2021-04-29","2021-05-12","2021-07-20","2021-07-30","2020-09-24","2020-12-18","2021-07-17","2021-04-24","2021-07-23","2021-09-11","2020-05-23","2021-02-15","2021-12-05","2020-12-17","2021-03-22","2021-05-03","2021-08-21","2021-10-08","2021-01-18","2021-01-25","2021-07-19","2021-02-02","2020-09-07","2021-07-10","2020-05-08","2021-04-25","2021-06-04","2021-09-25","2021-03-07","2020-05-24","2020-06-04","2021-07-13","2022-01-09","2021-09-05","2020-10-18","2020-04-29","2020-12-25","2021-05-29","2021-09-09","2020-10-19","2021-05-07","2021-07-11","2020-05-10","2020-12-22","2020-04-26","2020-08-22","2020-12-30","2021-04-21","2020-04-21","2021-09-06","2020-11-06","2021-06-20","2021-06-27","2021-12-14","2020-07-05","2020-12-13","2021-07-08","2021-11-23","2021-12-27","2021-08-25","2020-10-05","2021-02-26","2021-06-28","2022-01-10","2021-09-26","2020-04-19","2020-06-05","2021-04-07","2021-06-01","2020-09-04","2022-01-08","2020-08-04","2021-08-23","2021-04-15","2021-05-21","2021-12-10","2020-06-17","2020-07-02","2020-04-13","2020-06-12","2020-10-29","2020-08-09","2021-10-20","2020-05-17","2020-06-25","2021-12-04","2021-12-12","2021-09-30","2020-12-23","2021-05-09","2021-06-17","2021-12-08","2020-12-21","2021-08-12","2021-01-05","2021-05-31","2020-07-03","2020-08-26","2021-08-24","2020-03-29","2020-12-12","2021-04-23","2020-10-13","2020-12-09","2021-02-21","2021-05-18","2021-06-13","2020-04-14","2020-08-07","2020-11-27","2021-07-03","2020-09-17","2021-04-26","2021-09-10","2020-07-21","2020-11-16","2021-05-10","2021-05-28","2020-09-03","2020-09-16","2020-11-09","2021-02-05","2021-08-01","2021-12-01","2020-08-16","2020-05-30","2020-12-16","2021-03-21","2020-04-06","2020-08-13","2020-08-20","2020-06-15","2020-05-25","2021-02-10","2020-04-23","2020-05-19","2020-10-30","2021-01-19","2020-06-10","2020-07-12","2020-11-19","2021-05-27","2021-